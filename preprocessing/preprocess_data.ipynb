# %%
#import os

DATASET_PATH = "Bone_Fracture_Binary_Classification"

# Count images in each category
for split in ["train", "val", "test"]:
    for category in ["fractured", "not fractured"]:
        path = os.path.join(DATASET_PATH, split, category)
        num_images = len(os.listdir(path))
        print(f"{split}/{category}: {num_images} images")
# Out:
# train/fractured: 4606 images
# train/not fractured: 4640 images
# val/fractured: 337 images
# val/not fractured: 492 images
# test/fractured: 238 images
# test/not fractured: 268 images

# %%
#import glob

# Get sample filenames
sample_files = glob.glob(os.path.join(DATASET_PATH, "train", "fractured", "*"))[:5]
print("Sample Filenames:")
for f in sample_files:
    print(f)
# Out:
# Sample Filenames:
# Bone_Fracture_Binary_Classification/train/fractured/63.jpg
# Bone_Fracture_Binary_Classification/train/fractured/91-rotated3-rotated1-rotated1 - Copy (1).jpg
# Bone_Fracture_Binary_Classification/train/fractured/81-rotated1-rotated2-rotated2.jpg
# Bone_Fracture_Binary_Classification/train/fractured/2-rotated1-rotated1 - Copy (1).jpg
# Bone_Fracture_Binary_Classification/train/fractured/189.jpg

# %%
import cv2
import matplotlib.pyplot as plt

print("✅ OpenCV and Matplotlib are installed correctly!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ✅ OpenCV and Matplotlib are installed correctly!

# %%
fig, axes = plt.subplots(1, 5, figsize=(15, 5))
for i, file in enumerate(sample_files[:5]):
    img = cv2.imread(file)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB (for proper display)
    axes[i].imshow(img)
    axes[i].axis("off")
plt.show()

# %%
# Function to get image dimensions
def get_image_dimensions(image_paths):
    dimensions = []
    for img_path in image_paths:
        img = cv2.imread(img_path)
        if img is not None:  # Ensure the image is valid
            dimensions.append(img.shape[:2])  # (height, width)
    return dimensions

# Collect image sizes
sample_images = sample_files[:10]  # Check first 10 images
image_sizes = get_image_dimensions(sample_images)

# Print results
for i, size in enumerate(image_sizes):
    print(f"Image {i+1}: {size}")
# Out:
# Image 1: (751, 396)
# Image 2: (224, 224)
# Image 3: (224, 224)
# Image 4: (224, 224)
# Image 5: (585, 480)

# %%
#from collections import Counter

# Check dimensions for all train images
all_image_paths = glob.glob(os.path.join(DATASET_PATH, "train", "fractured", "*")) + \
                  glob.glob(os.path.join(DATASET_PATH, "train", "not fractured", "*"))

# Get all unique image sizes
all_sizes = get_image_dimensions(all_image_paths)
size_counts = Counter(all_sizes)

# Print out the most common image sizes
print("Unique image sizes and their counts:")
for size, count in size_counts.most_common(10):  # Show top 10 most common sizes
    print(f"Size {size}: {count} images")
# Out:
# libpng warning: bKGD: invalid
# libpng warning: bKGD: invalid
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50
# libpng warning: bKGD: invalid
# libpng warning: iCCP: known incorrect sRGB profile
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Unique image sizes and their counts:
# Size (224, 224): 8538 images
# Size (454, 373): 49 images
# Size (2880, 2304): 39 images
# Size (373, 454): 11 images
# Size (100, 100): 11 images
# Size (1693, 1353): 9 images
# Size (2920, 2320): 8 images
# Size (380, 285): 7 images
# Size (442, 442): 6 images
# Size (2021, 1099): 6 images

# %%
import os
import cv2
import glob
import numpy as np
from tqdm import tqdm  # Progress bar

# Define paths
RAW_DATA_DIR = "Bone_Fracture_Binary_Classification"
OUTPUT_DIR = "preprocessed_dataset"
TRAIN_DIR = os.path.join(OUTPUT_DIR, "train")
TEST_DIR = os.path.join(OUTPUT_DIR, "test")
VAL_DIR = os.path.join(OUTPUT_DIR, "val")

# Image size for Faster R-CNN (fixed resolution)
IMG_SIZE = (512, 512)

# Create output directories
os.makedirs(TRAIN_DIR + "/fractured", exist_ok=True)
os.makedirs(TRAIN_DIR + "/not fractured", exist_ok=True)
os.makedirs(TEST_DIR + "/fractured", exist_ok=True)
os.makedirs(TEST_DIR + "/not fractured", exist_ok=True)
os.makedirs(VAL_DIR + "/fractured", exist_ok=True)
os.makedirs(VAL_DIR + "/not fractured", exist_ok=True)

# Function to preprocess images
def preprocess_and_save_images(input_folder, output_folder):
    """Resizes and normalizes images, skipping corrupted files."""
    image_paths = glob.glob(os.path.join(input_folder, "*"))
    
    for img_path in tqdm(image_paths, desc=f"Processing {input_folder}"):
        try:
            img = cv2.imread(img_path)
            
            if img is None:
                print(f"Skipping unreadable image: {img_path}")
                continue  # Skip unreadable images

            img_resized = cv2.resize(img, IMG_SIZE)  # Resize
            img_normalized = img_resized / 255.0  # Normalize (scale to 0-1)
            
            # Save image
            output_file = os.path.join(output_folder, os.path.basename(img_path))
            cv2.imwrite(output_file, (img_normalized * 255).astype(np.uint8))  # Convert back to 0-255

        except Exception as e:
            print(f"Error processing {img_path}: {e}")

# Apply preprocessing
for split in ["train", "test", "val"]:
    for category in ["fractured", "not fractured"]:
        preprocess_and_save_images(
            os.path.join(RAW_DATA_DIR, split, category),
            os.path.join(OUTPUT_DIR, split, category)
        )

print("✅ Preprocessing complete! Check the 'preprocessed_dataset' folder.")
# Out:
# Processing Bone_Fracture_Binary_Classification/train/fractured:   6%|▌         | 281/4606 [00:00<00:15, 274.28it/s]libpng warning: bKGD: invalid
# Processing Bone_Fracture_Binary_Classification/train/fractured:  12%|█▏        | 537/4606 [00:01<00:11, 349.98it/s]libpng warning: bKGD: invalid
# Processing Bone_Fracture_Binary_Classification/train/fractured:  13%|█▎        | 613/4606 [00:01<00:11, 350.30it/s]
# Skipping unreadable image: Bone_Fracture_Binary_Classification/train/fractured/26(1).jpg
# Processing Bone_Fracture_Binary_Classification/train/fractured:  15%|█▍        | 690/4606 [00:02<00:10, 365.05it/s]libpng warning: iCCP: known incorrect sRGB profile
# Processing Bone_Fracture_Binary_Classification/train/fractured:  19%|█▉        | 883/4606 [00:02<00:10, 351.42it/s]
# Skipping unreadable image: Bone_Fracture_Binary_Classification/train/fractured/159.jpg
# Processing Bone_Fracture_Binary_Classification/train/fractured:  47%|████▋     | 2157/4606 [00:06<00:06, 357.00it/s]libpng warning: iCCP: known incorrect sRGB profile
# Processing Bone_Fracture_Binary_Classification/train/fractured:  66%|██████▌   | 3033/4606 [00:08<00:04, 326.78it/s]libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50
# Processing Bone_Fracture_Binary_Classification/train/fractured:  87%|████████▋ | 4001/4606 [00:11<00:01, 361.48it/s]libpng warning: bKGD: invalid
# Processing Bone_Fracture_Binary_Classification/train/fractured:  88%|████████▊ | 4075/4606 [00:11<00:01, 324.45it/s]
# Skipping unreadable image: Bone_Fracture_Binary_Classification/train/fractured/2.jpg
# Processing Bone_Fracture_Binary_Classification/train/fractured:  92%|█████████▏| 4229/4606 [00:12<00:01, 359.16it/s]libpng warning: iCCP: known incorrect sRGB profile
# Processing Bone_Fracture_Binary_Classification/train/fractured: 100%|██████████| 4606/4606 [00:13<00:00, 346.55it/s]
# Processing Bone_Fracture_Binary_Classification/train/not fractured:   3%|▎         | 121/4640 [00:00<00:10, 416.71it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/train/not fractured:  16%|█▌        | 751/4640 [00:01<00:09, 407.76it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/train/not fractured:  28%|██▊       | 1294/4640 [00:03<00:09, 359.89it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/train/not fractured:  32%|███▏      | 1463/4640 [00:03<00:08, 394.68it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/train/not fractured:  83%|████████▎ | 3839/4640 [00:10<00:02, 348.05it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/train/not fractured:  84%|████████▎ | 3879/4640 [00:10<00:02, 360.04it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/train/not fractured: 100%|██████████| 4640/4640 [00:12<00:00, 369.34it/s]
# Processing Bone_Fracture_Binary_Classification/test/fractured: 100%|██████████| 238/238 [00:01<00:00, 206.18it/s]
# Processing Bone_Fracture_Binary_Classification/test/not fractured:   0%|          | 0/268 [00:00<?, ?it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/test/not fractured:  18%|█▊        | 47/268 [00:00<00:01, 214.31it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/test/not fractured:  26%|██▌       | 69/268 [00:00<00:00, 200.35it/s]Premature end of JPEG file
# Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/test/not fractured:  75%|███████▌  | 202/268 [00:01<00:00, 186.74it/s]Premature end of JPEG file
# Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/test/not fractured: 100%|██████████| 268/268 [00:01<00:00, 155.98it/s]
# Processing Bone_Fracture_Binary_Classification/val/fractured:   0%|          | 0/337 [00:00<?, ?it/s]libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50
# Processing Bone_Fracture_Binary_Classification/val/fractured: 100%|██████████| 337/337 [00:01<00:00, 188.75it/s]
# Processing Bone_Fracture_Binary_Classification/val/not fractured:   0%|          | 0/492 [00:00<?, ?it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/val/not fractured:  18%|█▊        | 89/492 [00:00<00:01, 261.92it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/val/not fractured:  24%|██▎       | 116/492 [00:00<00:01, 240.84it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/val/not fractured:  29%|██▊       | 141/492 [00:00<00:01, 213.98it/s]Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/val/not fractured:  81%|████████  | 399/492 [00:01<00:00, 260.57it/s]Premature end of JPEG file
# Premature end of JPEG file
# Processing Bone_Fracture_Binary_Classification/val/not fractured: 100%|██████████| 492/492 [00:02<00:00, 213.47it/s]
# ✅ Preprocessing complete! Check the 'preprocessed_dataset' folder.

# %%
import cv2
import matplotlib.pyplot as plt

sample_image = "preprocessed_dataset/train/fractured/0.jpg"  # Replace with an actual filename

img = cv2.imread(sample_image)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
plt.imshow(img)
plt.axis("off")
plt.show()
